# %% [markdown]
# # 7.2.5 Hands-on with NLLB

# %% [markdown]
# ## Installation

# %%
# !wget https://raw.githubusercontent.com/VincentCCL/MTAT/refs/heads/main/code/nllb_translate.py
# !pip -q install evaluate sacrebleu
# Out:
# --2026-03-18 15:16:12--  https://raw.githubusercontent.com/VincentCCL/MTAT/refs/heads/main/code/nllb_translate.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4579 (4.5K) [text/plain]
# Saving to: ‘nllb_translate.py’
#
# nllb_translate.py   100%[===================>]   4.47K  --.-KB/s    in 0s
#
# 2026-03-18 15:16:13 (65.0 MB/s) - ‘nllb_translate.py’ saved [4579/4579]
#
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 6.8 MB/s eta 0:00:00

# %% [markdown]
# ## Usage

# %%
# %run nllb_translate.py \
  --model-dir facebook/nllb-200-distilled-600M \
  --src-lang eng_Latn \
  --tgt-lang nld_Latn \
  --src-file /kaggle/input/datasets/vincentvandeghinste/tatoeba-en-nl/dev.en \
  --out-file dev.nllb.nl \
  --ref-file /kaggle/input/datasets/vincentvandeghinste/tatoeba-en-nl/dev.nl \
  --metrics bleu,chrf \
  --batch-size 32 \
  --max-src-len 128 \
  --max-gen-len 128 \
  --num-beams 4
# Out:
# config.json:   0%|          | 0.00/846 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# ...
# tokenizer.json:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/512 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# The tied weights mapping and config for this model specifies to tie model.shared.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie model.shared.weight to model.decoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# ...
