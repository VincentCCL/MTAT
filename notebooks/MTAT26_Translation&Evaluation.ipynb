# %% [markdown]
# <a href="https://colab.research.google.com/github/VincentCCL/MTAT/blob/main/notebooks/MTAT26_Translation%26Evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this hands-on session we will see how we can send sentences to online translation engines, and how we can automatically evaluate the results, provided that we have human translated reference translations at our disposal.

# %% [markdown]
# # 3.4.1 Accessing Translation engines in Python
# We can connect python to existing online translation engines by using their so-called *API*s: Application Programming Interface.
#
# We first need to install the python module *translators*, which allows easy access to several online engines. For more info on this module check https://pypi.org/project/translators/.
#
# For python, we install modules with the `pip install` command. We tell Google Colab that the code cell does not concern python code, but contains a linux command by prepending it with a `!`.

# %%
# !pip -q install translators --upgrade

# %% [markdown]
# To show how it works, we will use a set of Dutch sentences created as the development set of the Tatoeba English-to-Dutch parallel data.
#
# We download the testset using `!wget`.

# %%
# !wget https://raw.githubusercontent.com/VincentCCL/MTAT/refs/heads/main/data/tatoeba-en-nl/dev.en
# Out:
# --2026-02-18 14:51:26--  https://raw.githubusercontent.com/VincentCCL/MTAT/refs/heads/main/data/tatoeba-en-nl/dev.en
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 32441 (32K) [text/plain]
# Saving to: ‘dev.en’
#
# dev.en              100%[===================>]  31.68K  --.-KB/s    in 0.003s
#
# 2026-02-18 14:51:26 (10.2 MB/s) - ‘dev.en’ saved [32441/32441]

# %% [markdown]
# We then read in the files in python, in the list `sourcelines`.

# %%
sourcefile = "dev.en"
sourcelines=open(sourcefile,'r').readlines()
sourcelines = [l.strip() for l in sourcelines]
sourcelines
# Out:
# ['Nobody reads about my country .',
#  'I sleep in my car .',
#  "There 're clean sheets under the bed .",
#  'I have a donkey .',
#  'Betty drives fast .',
#  'Come to help me .',
#  "She 's not penniless .",
#  'This mountain is covered in snow all-year-round .',
#  'Tom thought Mary was cute .',
#  "I don 't suppose it 's possible to read a book by moonlight .",
#  'You just have to find her .',
#  "It 's very cold today .",
#  'Can you ship it to New York City ?',
#  'What else does Tom want ?',
#  "I 'd like to buy a Picasso .",
#  "I don 't mind your groping in the dark for a solution , but I wish you 'd come to a decision .",
#  'Tom has his own business .',
#  'Horses run fast .',
#  'I feel depressed .',
#  'How did your test go ?',
#  'What would you do if you were in my place ?',
#  'Take a short cut .',
#  'What is the name of this river ?',
#  'Lisa speaks not only English but also French .',
#  'Tom said that he needed to go to bed .',
#  "I don 't drink wine .",
#  "We 're a little busy now .",
#  'Tom offended Mary .',
#  'Learn these sentences .',
#  'It is all delicious !',
#  'Are you a man or a spider ?',
#  'It was an advantage having learned Chinese while I was in school .',
#  'If this is a dream , I will kill the man who wakes me up .',
#  'Tom started writing .',
#  'I love to dance .',
#  'What beautiful flowers !',
#  'Do you drink alcohol every day ?',
#  'I kept telling myself that it would all be over soon .',
#  'Maya priests learned much about astronomy .',
#  'Afterwards , the witnesses testified .',
#  'She joined the navy after finishing college .',
#  'We have to wait for Tom .',
#  'Mary asked Tom to drive her to the airport .',
#  'Is that Mrs. Kent ?',
#  "That 's probably your toothbrush .",
#  'He is a head taller than me .',
#  "That 's why we are here .",
#  'These are gifts .',
#  "You won 't solve this kind of problem by talking about it ; you have to take action .",
#  'Does anyone disagree ?',
#  'I feel guilty .',
#  'I speak Basque .',
#  'There is a TV in this room .',
#  'He is studying .',
#  'What are you guys going to do today ?',
#  'Mary is updating her website .',
#  "Here 's a yellow rose .",
#  'Tom would cry .',
#  'Everyone except Tom ate pizza .',
#  '" Do you believe them ? " " No , they can \'t even keep their story straight . "',
#  "I 'm sorry I can 't help you now . I 'm busy .",
#  'She came .',
#  'I used to be an adventurer like you , then I took an arrow in the knee .',
#  'Examine this .',
#  'He is standing on the stage .',
#  'I can help you .',
#  "Free advice isn 't always good advice .",
#  'Green suits you very well .',
#  "Here 's to our friendship .",
#  'Try to lose weight by jogging .',
#  'Happy Thanksgiving Day .',
#  "It was raining , and Joe 's long hair was completely wet by the time he got home .",
#  'Meat contains proteins .',
#  'I am who I am .',
#  "I 'm from South Holland .",
#  'What do you think it is ?',
#  'I love to travel .',
#  'I suggest you do that tomorrow .',
#  'She was eager to go home .',
#  'I like her dark eyes .',
#  'Why are you undressing ?',
#  'The girl playing the piano is Akiko .',
#  "The pump didn 't work properly .",
#  "I 'm looking for work .",
#  'Tom is very scared .',
#  'Tom rarely talks about his problems .',
#  'Correct !',
#  'What do you do in Japan ?',
#  'No one was able to replicate the results of that study .',
#  'Mary likes snow .',
#  'Draw a circle .',
#  'I was surfing on the internet at this time yesterday .',
#  "Tom didn 't have the right tools for the job .",
#  'Tom was scared to death .',
#  "We don 't need your help .",
#  'You should have seen the look on his face .',
#  'His parents came from Germany .',
#  'Would you like to drink anything ?',
#  'Did you buy tomatoes ?',
#  'This task is easy-peasy .',
#  'Thank you for the wonderful meal .',
#  'The penguin was expelled from the group .',
#  "I 'll be done working tomorrow .",
#  "I don 't want to be your girlfriend .",
#  'I love French coffee .',
#  'Tom said no .',
#  'Mary is Greek .',
#  'It will damage the crops .',
#  'We raced toward the fire .',
#  "Mine is bigger than Tom 's .",
#  'How many museums did you visit ?',
#  'He bowed to the Queen .',
#  'I like reading American novels .',
#  'Up yours !',
#  'My dad used to drive a Beetle .',
#  'Toki Pona is not a language to be spoken , but only to be read and written .',
#  'Tom killed a tiger .',
#  'If you stipulate that these things are true , I will sign the contract .',
#  'I want something cold to drink .',
#  'We are with you .',
#  "I 'll explain everything .",
#  'Tom told me he wanted to quit his job .',
#  'My son is ten years old .',
#  'Last night , I listened to radio .',
#  'They know how to make an atomic bomb .',
#  'The town was full of activity .',
#  'Once again .',
#  "You all don 't speak English .",
#  "Does Ken know Tom 's real name ?",
#  "I 'm learning how to type .",
#  'My mother was crying .',
#  "Tom always deceives us ; I don 't trust him .",
#  "That 's something like a movie scenario .",
#  'Tom made pancakes for you .',
#  'Tom says that he plans to stay in Australia .',
#  'Where is the kitchen ?',
#  'Which sentence do you prefer ?',
#  "That 's my cat .",
#  'Tom was bitten by a bat .',
#  'He is about thirty .',
#  'The third street to the right .',
#  'This is a statue of Mercury .',
#  'Tom speaks perfect French , but his native language is German .',
#  "I didn 't want it !",
#  'You love coffee .',
#  'Tom is openly gay .',
#  'Do what you think is best .',
#  "Let 's sit here on the grass .",
#  "I don 't know what we 'll do .",
#  'Bottle or glass ?',
#  'These glasses are beautiful .',
#  'This area is known for its beautiful scenery .',
#  'His attempt to escape was successful .',
#  "Let 's go by train .",
#  'Tom woke up feeling like a new man .',
#  'The beach is an ideal place for children to play .',
#  'Faster !',
#  'Does Tom like to swim ?',
#  'Why are you so disappointed ?',
#  'Tom sliced the carrots .',
#  'Arabic art , literature , and architecture flourished , forming the ethnic identity that has continued to exist to the present day . This was what is called the Golden Age of Islam .',
#  'The match has been canceled due to heavy rain .',
#  "You 're welcome .",
#  'This is what I want .',
#  "I don 't know how to pronounce Tom 's last name .",
#  'Maria is taller than her girlfriend .',
#  'He made it known where the president had gone .',
#  'Is this art ?',
#  'She makes me happy .',
#  "I think he 's playing really well .",
#  'Please play the violin .',
#  'Have they connected the radio antenna ?',
#  'As a man lives , so shall he die .',
#  'I have plenty of time left .',
#  'He stopped smoking .',
#  'When air dries , it makes thirsty and cough .',
#  'That documentary about the environmental crisis was a real eye-opener .',
#  'Tom has found a job .',
#  'Look at me when I talk to you .',
#  'We have a farm .',
#  'Does he like beer ?',
#  "He 's my brother .",
#  'In Malta they speak Maltese .',
#  "I don 't want to be your enemy .",
#  "Dad needs to take a rest . He 's been working in the garden for three hours .",
#  'I wrote a long letter to her .',
#  'He sat in the back .',
#  'At night he goes out to have a drink .',
#  'I was not sure what to do .',
#  'Mary returned the book that she had borrowed from the library .',
#  "It 's my CD .",
#  'She was already heading for the door .',
#  'Mary put on her socks .',
#  "Let 's take a short pause .",
#  'Do you regret marrying me ?',
#  'The light generated in the Big Bang still travels through space at a speed of 300,000 km / s .',
#  "I 'm trying to solve the problem .",
#  "' ' All men must die . ' ' ' ' All men must serve . ' '",
#  'Wellington is the capital of New Zealand .',
#  'You must keep your room clean .',
#  'You know why .',
#  'I am drinking his beer .',
#  'As Tom is honest , I like him .',
#  'I met him yesterday .',
#  'He wanted to be rich .',
#  'It works .',
#  'This hat is yours .',
#  'That island has a tropical climate .',
#  'My grandfather died shortly after my birth .',
#  'A meal without wine is like a day without sunshine .',
#  'Lets get the fuck out of here .',
#  "I 'm sick and tired of your lies .",
#  "I 'm drinking my coffee .",
#  'He took advantage of my youth .',
#  'Tom can cook very well .',
#  "You 'll never find him .",
#  "I was hoping you 'd let me buy you a slice of pizza .",
#  'Go away !',
#  'He told me that he wanted to practice his English with me .',
#  'His behavior is my primary concern .',
#  'I did it just now .',
#  'He does not play baseball .',
#  'I like the one with a white belt .',
#  "It 's mustard after the meal .",
#  'Water freezes at zero degrees Celsius .',
#  'She helped us .',
#  'Do what she tells you .',
#  'Tom is afraid of spiders .',
#  "I 'm not feeling so good .",
#  "The ship leaves at 7 o 'clock .",
#  'I rented a snowboard .',
#  'I met him once .',
#  'Which book is yours ?',
#  'Do you feel pain when you do that ?',
#  'Do you speak Toki Pona ?',
#  "Don 't move a muscle !",
#  "What 'll we do ?",
#  "I wonder why Tom isn 't wearing a lab coat .",
#  'Do you take MasterCard ?',
#  'My brother talks too much .',
#  'He was laughed at by everybody .',
#  "I think I 've broken my arm .",
#  'He explained the rule to me .',
#  'Sami needed a dictionary .',
#  'I forgot to take my medicine .',
#  "I 'm free tonight .",
#  'Are you on Facebook ?',
#  'She heard him sing .',
#  'Does anyone here speak English ?',
#  "The poker player stared down at the cards in his hand like they held the answers to life 's great mysteries .",
#  'The history of all hitherto existing societies is the history of class struggles .',
#  'Sami ordered four pizzas .',
#  "What Tom did wasn 't legal .",
#  "He 's turning eighteen today .",
#  'She laid her baby on the bed .',
#  'Are you twins ?',
#  'You work too much .',
#  'The moon was shining bright .',
#  'She was raised in France .',
#  'There is no rush .',
#  "I 'll get in touch with Jim and ask him to come over .",
#  "I 'll pay you for everything .",
#  "I 'm here to protect you .",
#  "I found something I thought I 'd lost .",
#  'Do you have a pen ?',
#  "It 's already seven o 'clock .",
#  'You look satisfied .',
#  'Did you say that I could never win ?',
#  'Is this strange ?',
#  'Tom looks very nervous .',
#  'I am eating rice .',
#  'Is Tom here ?',
#  'Layla had a lesbian affair .',
#  'It was my turn to clean the room .',
#  'The longer you live , the more you see .',
#  'Have you ever been to Paris ?',
#  'About two million pounds of flour are exported annually .',
#  "Sorry , I don 't speak Greek .",
#  'Pink roses are beautiful .',
#  'I speak Russian .',
#  "Let 's change the subject .",
#  'The man all in red was holding a gun .',
#  'We have to boycott them .',
#  'Mary is my wife , and I am her spouse .',
#  'Your friends will regret your absence .',
#  'Tom has a nose ring .',
#  'The chickens are in the henhouse .',
#  'She is in Berlin .',
#  'Are you on your way home ?',
#  'Are you able to keep walking ?',
#  'I wear contact lenses .',
#  "What 's the difference between a rabbit and a hare ?",
#  'Where is the librarian ?',
#  'Accidents happen all the time .',
#  'Your mother must have been beautiful when she was young .',
#  'Hi !',
#  'This school was founded in 1650 .',
#  'He announced the next singer .',
#  'Tom was sound asleep when Mary walked into the room .',
#  'He is very kind .',
#  'Why did you come to Malaysia ?',
#  'I live in India .',
#  "She doesn 't have a driving licence .",
#  'Her birthday is May 5th .',
#  'Do you work with Tom ?',
#  'I wish her a good night .',
#  'Tom waited inside .',
#  'How long will you stay in town ?',
#  'How many museums did you visit ?',
#  'I thought you liked to learn new things .',
#  "I 'm from Zambia .",
#  "I 'm not satisfied with what you 've done .",
#  "That 's a great poem .",
#  'He is trying to reach the top of the mountain .',
#  'Why was it so hard to establish that the neuron is the most basic unit of nervous tissue ?',
#  'Sam went skiing in January .',
#  'Dan was also arrested .',
#  "It 's really personal .",
#  'We live in Hungary .',
#  'Mary is playing football .',
#  "I don 't know how to cook .",
#  "I don 't know Tom 's last name .",
#  'Your brother is sick .',
#  'Is Tom looking ?',
#  "I 'd rather avoid it .",
#  "Don 't you smoke ?",
#  'Guinea is called " Guinée " in French .',
#  'Sweden is called " Sverige " in Swedish .',
#  'How much did the bread cost ?',
#  'Popular movements express popular displeasure .',
#  'I lost my shoe in the fire .',
#  'As George Bush has amply demonstrated , being president of the U.S. requires only a modicum of intelligence .',
#  'No way !',
#  'He was standing behind the door .',
#  "Why wouldn 't we do that ?",
#  'I remember hearing about Tom .',
#  'They believe you .',
#  'Tom told everybody he was exhausted .',
#  'Who did you get this from ?',
#  'If you do this , you will regret it for the rest of your life .',
#  "Snip , snap , snout , this tale 's told out .",
#  "She didn 't have enough money .",
#  "Tom and Mary said that they weren 't colorblind .",
#  'Are there any loose cables ?',
#  "He 's eating a tomato .",
#  "Give a man a mask and he 'll tell the truth .",
#  "Gosh , I 'm 25 years old now . Isn 't that horrible ? Rounding up , I 'm 30 !",
#  'No one wanted to talk .',
#  "Tom just doesn 't listen .",
#  'He is a soccer player .',
#  'How would you define " happiness " ?',
#  'You could have come stay with us .',
#  'The hare is bleeding from its ear .',
#  'Regrettably , I cannot agree with you .',
#  'I have three children .',
#  'What is the entrance fee ?',
#  'I have taken enough photos . Thank you .',
#  'Tunupa was born in Bolivia .',
#  "No , I 'm not Mary . My name is Theresa .",
#  "I don 't want it at all .",
#  'Tom and Mary both work in Boston .',
#  "I 'm Tom 's stepfather .",
#  'A second opinion would be very helpful .',
#  'She touched his hand .',
#  'Their living room was engulfed in flames .',
#  "Do you know who 's behind you ?",
#  'Tom has done that already .',
#  'The penis is one of the masculine sexual organs .',
#  "It 's double Dutch to me .",
#  'Is what they say about you true ?',
#  'You were supposed to wait .',
#  'South Africa is called " iNingizimu Afrika " in Zulu .',
#  'Salvador Dalí was a Spanish artist .',
#  'Tom said he knew Mary .',
#  'I saw Tom three hours ago .',
#  'Why would Tom have been here ?',
#  'The popular singer committed suicide .',
#  'Tom is someone who many people say should not be around kids without supervision .',
#  'His car is really cool .',
#  'We played on the beach .',
#  'Is that your umbrella ?',
#  'Do you speak Arabic ?',
#  'Where are your kids ?',
#  'I want to be more independent .',
#  'Is this seat reserved ?',
#  "He 's trying to commit suicide .",
#  'Can you help ?',
#  'They are vegetarians .',
#  'He killed himself .',
#  "Who 's on duty today ?",
#  'Do you know what causes that ?',
#  'My cousin has been calling .',
#  'I remember having seen her some place .',
#  'Please open your suitcase .',
#  "I 'll miss you guys .",
#  'What do you want to do with your life ?',
#  'Is this material useful for our project ?',
#  'I need a painkiller .',
#  'We drink too little water .',
#  "Tom wasn 't wounded .",
#  'Albania is called " Shqipëria " in Albanian .',
#  "I 'll go change my clothes .",
#  'I messed it all up .',
#  'I found that embarrassing .',
#  'I got a pair of new shoes .',
#  "Don 't talk to me !",
#  'A minute later we were both in a hansom , driving furiously for the Brixton Road .',
#  'Tom drove his car off a cliff .',
#  'They went to Ibiza .',
#  'The restaurant was almost empty .',
#  'I am reading his book .',
#  'I have a couple of questions for you .',
#  "It 's almost dark .",
#  'Please drink tea .',
#  'The news made him happy .',
#  'You remind me of my father .',
#  'Tom made the right decision after all .',
#  'This graph is misleading .',
#  'I speak English every day .',
#  'I was being ironic .',
#  'Sami wanted to marry a Muslim woman .',
#  'The police caught the burglar red-handed .',
#  'Do you dress fashionably ?',
#  'We learn English at school .',
#  'Tom watched a movie with Mary .',
#  'Do you have any brothers ?',
#  'What are you still doing here ?',
#  'The girl is ugly .',
#  'Wait for me .',
#  'Are you her mother ?',
#  'Mike is waiting downstairs .',
#  'We have enough water .',
#  'Please give my best regards to Judy .',
#  'My grandma gave me this necklace .',
#  "Who 's that boy ?",
#  'You must do it for yourself .',
#  "Sorry , I don 't think I 'm gonna be able to .",
#  "Please don 't smoke .",
#  'Earth , Mars and Jupiter are planets .',
#  'Do you speak Klingon ?',
#  'Is Tom able to eat ?',
#  'I saw your sister the day before yesterday .',
#  "Please give me your picture so I don 't forget how you look .",
#  'Tom likes to read manga online .',
#  'Act your age .',
#  "I thought you said Tom didn 't live in Boston anymore .",
#  'It is hard to adapt this story for children .',
#  "You 're dangerous .",
#  'I brought one just in case .',
#  "I eat breakfast at eight o 'clock .",
#  'I lost my watch .',
#  "Let 's push on .",
#  "I don 't like eating tomatoes .",
#  'This is just water .',
#  'She embarrassed me in front of my friends .',
#  'How do you do ?',
#  'Have you ever been abroad ?',
#  "That 's an interesting plan .",
#  'We found the right place .',
#  'I need a computer .',
#  "Tom didn 't know that Mary understood French .",
#  'I think you have made a mistake .',
#  'Did you know Tom had a twin brother ?',
#  'She is making tea .',
#  'Tom is last .',
#  'I have been struck by lightning twice .',
#  "There isn 't much time .",
#  'Spanish is spoken in twenty countries .',
#  "Worrying is like paying a debt you don 't owe .",
#  'In any case , you need to vote " yes " in the February 18th referendum .',
#  "Turtles don 't have teeth .",
#  'Are aliens real ?',
#  'Both of us are from Tampa .',
#  'Thanks for the gift .',
#  'I come from Trondheim .',
#  'She sells sea shells .',
#  'Can you play the piano ?',
#  'I once wanted to be an astrophysicist .',
#  'She is aggressive .',
#  "Tom says it 's an emergency .",
#  'We need more room .',
#  'Turn left !',
#  'I have a first aid kit in my car .',
#  "He 's wearing a strange hat .",
#  'Do you have kids ?',
#  'Tom looks worried .',
#  'He is very fond of music .',
#  "Don 't touch anything without asking first .",
#  'The cost of living is very high in Tokyo .',
#  'Say hello .',
#  "I don 't use Facebook .",
#  'What do you want to eat ?',
#  'What are you doing next Monday ?',
#  'The exposition was very interesting .',
#  'You are guilty of murder .',
#  'How much is this pen ?',
#  'Look at that tall building .',
#  'Most bears are omnivores .',
#  'A thief broke in and made off with all my jewelry .',
#  "Lisa , this is Mr Murata . He 's my boss .",
#  'Will you sing some English songs for us ?',
#  'It is not clear when and where she was born .',
#  'She is upset .',
#  'Our next-door neighbor has been missing for several months now .',
#  'Have you guys seen him today ?',
#  'Mary coughed .',
#  'What is happening ?',
#  'I can place the palms of my hands on the floor without bending my knees .',
#  'Do you like powder-snow skiing ?',
#  "I didn 't know that Tom lived in Australia for three years .",
#  'Anna likes chocolate .',
#  'I just received your message yesterday .',
#  "You shouldn 't run around with a toothbrush in your mouth .",
#  "She 's faking .",
#  "I know you 're in love with me .",
#  "On Mondays , he 's always at home .",
#  'Tom was the last to arrive .',
#  'Thanks , I understood everything .',
#  "It 's cloudy .",
#  'Getting used to it will take time .',
#  'Did you write this ?',
#  'Is this interesting to translate ?',
#  'Give me a few .',
#  'I like Sachiko better than Akiko .',
#  'I am your friend .',
#  'I burned my finger .',
#  'Was Tom there ?',
#  "She 's in dire straits .",
#  "We shouldn 't have stayed up all night .",
#  'That was the right thing to do .',
#  "She couldn 't come because she was sick .",
#  'Do you use spice or K2 ?',
#  'I would like to have a look at your collection of stamps .',
#  'The audience shouted " Bravo ! " for at least a full minute .',
#  "He 's talking so loudly that we 're going to get in trouble .",
#  "Buses in the country don 't usually come on time .",
#  'Uzbekistan is called " O \'zbekiston " in Uzbek .',
#  "I 'd like to get off at the next stop .",
#  'Sami was interested in Islam .',
#  'Look up the phrase in your dictionary .',
#  'Tom and Mary are visiting relatives .',
#  'Why did she run ?',
#  'Mary thought that she would never see her son again .',
#  'He should have bought some pencils .',
#  'Everything is possible .',
#  'I prefer to do it alone .',
#  'How noisy this street is !',
#  'Why pretend ?',
#  'Has anybody been helping you ?',
#  "It 's possible .",
#  'I understand your language .',
#  'Butter is made from milk .',
#  'I wish to go to Hawaii .',
#  'I found the key I had been looking for .',
#  "She 'll understand .",
#  'Brian took some roses .',
#  'Tom encouraged me to learn French .',
#  "Mary doesn 't do it .",
#  'Mature is better .',
#  'I like eating tomatoes .',
#  "I don 't know whether Tom has a bicycle or not .",
#  'Esther lives in New York with her wives .',
#  "That 's one way to ruin a good scene .",
#  'Where is a nearby pharmacy ?',
#  'Get in the queue .',
#  'Tom put the folder on the table .',
#  "I 'm learning Esperanto .",
#  'How lovely !',
#  'I hope we have fine weather tomorrow .',
#  'I just emailed you .',
#  'He woke up to find himself lying on a bench in the park .',
#  'I have a daughter living in Australia .',
#  'Different strokes for different folks .',
#  'There is nothing left in the fridge .',
#  'Do your best .',
#  'Nobody supported my country .',
#  "They don 't care .",
#  "I 've gained a little bit of weight .",
#  "I won 't pay my son 's debts .",
#  'I expect that everyone will do that tomorrow .',
#  "I don 't trust his story .",
#  'Let me entertain you .',
#  'All of this stationery is his .',
#  "It 's not as cold today as it was yesterday .",
#  'Can you speak Indonesian ?',
#  'Everything depends upon the results .',
#  'Turn off the light on leaving the room .',
#  'Tom bought a scarf for Mary .',
#  'May I ask your name ?',
#  'You can see a lot of stars in the sky .',
#  'My hair has grown too long .',
#  'How often do you check your smartphone ?',
#  'Tom came last .',
#  'Tom remains suspicious .',
#  'Not all Jews are religious .',
#  'The mayor is not available now .',
#  'I want to teach French .',
#  "I haven 't heard that joke in ages .",
#  "Sport doesn 't interest me .",
#  'French bread is delicious .',
#  'The prize was divided equally among the ten syndicate members .',
#  'Fire is the only thing that can kill zombies .',
#  'I sent it by post .',
#  'Tom rented a snowboard .',
#  'We are in the era of atomic energy .',
#  'She was unamused by the joke .',
#  'We tried in vain to make him change his mind .',
#  'Tom comes here every other week .',
#  'The boy has a newspaper .',
#  'Tom and Mary got married in Boston .',
#  'There is a bookstore just around the corner .',
#  'Tom leaned forward to listen .',
#  "It 's incredible !",
#  'I always drink a cup of coffee in the morning .',
#  'Tom was cheering .',
#  'The kitchen is not clean .',
#  'I found the light switch .',
#  'I need a little help !',
#  'We exaggerated .',
#  'I know that I am wrong .',
#  "I 'm gay , so what ?",
#  "You must come back before nine o 'clock .",
#  'Open your heart .',
#  'Tom opened the beer .',
#  'Would you like some coffee ?',
#  'Again .',
#  'They ambushed the enemy .',
#  'Mr. Brown has four children .',
#  'Well done !',
#  'How is your family ?',
#  'How beautiful you are today !',
#  "That 's an interesting piece of information .",
#  'I arrived at school on time .',
#  'They tasted the bread .',
#  'My father used to drink till late at night .',
#  'The floor was covered with blood .',
#  'Did you require any special assistance when you were in school ?',
#  "We both know this isn 't real .",
#  'Tom will move back to Australia .',
#  'She follows the latest craze .',
#  'Do you know why cactus have needles ?',
#  "Let 's hope Tom stays healthy .",
#  "You 'll have to learn all these dates by rote .",
#  "People with zoanthropy believe they 've changed into an animal .",
#  'Oslo is the most populous city in Norway .',
#  'She has blue eyes and blonde hair .',
#  'I want to talk to you about something .',
#  "I haven 't been here in a long time .",
#  'What time are you going on duty ?',
#  'Watch out ! The car almost ran over you .',
#  'Darn !',
#  'It is time to go .',
#  'We have to put off the game till next Sunday .',
#  "That 's unimportant .",
#  'If you lend someone $ 20 and never see that person again , it was probably worth it .',
#  'How did he manage to flip over a truck ?',
#  'They promise us the moon , but I suspect we can wait for the fulfillment of those promises till hell freezes over .',
#  'Have you ever seen a rainbow ?',
#  'The cows behind my house only eat tulips .',
#  "What 've you been doing today ?",
#  'Where can I get a map ?',
#  'Feeding someone during the holy month of Ramadan is very rewarding .',
#  'She should know that .',
#  'Could you please tell me why you love her ?',
#  "You 're the first .",
#  'I would like to kiss you .',
#  'Is it free ?',
#  'She did it single-handedly .',
#  'I have 3 girlfriends .',
#  "He 's too cocky .",
#  'The soldier gave me water .',
#  'He adapted to his environment .',
#  'Donald started walking to class .',
#  'I go out sometimes for a beer .',
#  'Night is for sleeping .',
#  'Do you know Mr Bingley ?',
#  'Tom dyed his hair black .',
#  'I can handle Tom myself .',
#  'The facts speak for themselves .',
#  'It was not my fault .',
#  "It 's early .",
#  'Did you find your book ?',
#  'A bird has wings .',
#  'The new telescope was shipped in a huge wooden box .',
#  "I 'll wait here .",
#  "Tom shouldn 't have married Mary .",
#  'You need not prepare a formal speech .',
#  "It 's about five miles .",
#  'Now that I am a teacher , I think otherwise .',
#  'He won a silver medal .',
#  'When one part of an object is on fire , other parts of that object tend to light on fire as well . This is called a fire .',
#  'I was stupid enough to believe it .',
#  'Deliberate fraud in science needs to be distinguished from well-meaning questionable research practices .',
#  'Why is the light on ?',
#  'First time ?',
#  "I don 't have a pencil .",
#  "What 's your favorite car ?",
#  "Maybe he 's not young .",
#  'Atl is ten .',
#  'Tom was in his room all afternoon .',
#  'One billion people speak English .',
#  'Good God !',
#  "However often I phone I can 't get through .",
#  'We gave Sarah the apple .',
#  'The French are our friends .',
#  'Whose shoes are these ?',
#  'He predicted she would win .',
#  "Even if I wanted to , I couldn 't do that .",
#  'It was just a quirk of fate .',
#  'Who is the girl in the pink dress ?',
#  'Once again .',
#  'What fills the heart , will flow over from the mouth .',
#  'Take care of our planet .',
#  'Accidents will happen .',
#  'I ironed my handkerchiefs .',
#  'The real problem is not whether machines think but whether men do .',
#  'Tom came just after you left .',
#  'The leaves turn brown in the autumn .',
#  "I don 't have water .",
#  "He 's got a headache .",
#  'Did you give the food to the cat ?',
#  'Thai is the official language in Thailand .',
#  'Their internet speed is better than mine .',
#  'I am ugly .',
#  'He returned from Denmark .',
#  'I like to play poker .',
#  "Mary 's growing up bilingual : with Mum Akiko , she speaks Japanese , and with Dad Tom , she speaks German .",
#  'The man we saw in the park was Mr. Hill .',
#  "I don 't eat much meat .",
#  'He was a good king .',
#  'Your soul needs to be saved .',
#  'On an average , I go to the movies twice a month .',
#  "It 's always been like that .",
#  "I 'm your friend .",
#  'This is a very serious issue .',
#  'Do you speak Norwegian ?',
#  'You are my father .',
#  'Look , a tomato which grew up listening to Mozart !',
#  '" Is Tom on our team ? " " No , he \'s on the other team . "',
#  'I want to do everything .',
#  'Tom carried the suitcases for me .',
#  "I don 't care what Tom says . I 'm not going to go .",
#  'Tom likes to eat turtles .',
#  'The policeman took the knife from the boy .',
#  'Have you sent her my message ?',
#  'When the cat is away , the mice will play .',
#  'This is a pear , not an apple .',
#  'How much progress have you made ?',
#  'I always love the smell of roasted chestnuts .',
#  "He is a wolf in sheep 's clothing .",
#  'Tom searched the glove compartment for a map .',
#  "I 'm going to give you the book .",
#  'When are you going to Europe ?',
#  'The blood was bright red .',
#  'Can you hear me now ?',
#  'Do you know your size ?',
#  'Can you tell us what happened next ?',
#  'She was present at the party .',
#  'Have you ever applied for a job ?',
#  'What did you answer ?',
#  'I have math homework today .',
#  'Sadly , terrorism is a global disease , but it must never be allowed to triumph .',
#  'I already talked to this student .',
#  "I wasn 't affected by the flood .",
#  'You know nothing .',
#  'Someone has been in my room .',
#  'I can protect you .',
#  'She has two sisters , both of whom live in Tokyo .',
#  'It is with great pleasure that we welcome you here .',
#  "She didn 't believe the rumor .",
#  'Father keeps a diary every day .',
#  "I wonder if that 's Tom .",
#  'For some reason I feel more alive at night .',
#  'You sang .',
#  'Are you free tonight ?',
#  "I didn 't know Tom use to live in Boston .",
#  'Bears like honey .',
#  'The farm owner has a large farm .',
#  'Do you think I need to go ?',
#  'Do you know how much you weigh ?',
#  'Mr Suzuki is a great scientist .',
#  'How delicious !',
#  "Tom and Mary didn 't have a choice .",
#  'He lives in a world of fantasy .',
#  "He didn 't get the joke .",
#  'Everybody loves it .',
#  "I thought you didn 't want to talk about what happened .",
#  "I don 't understand how someone so rich can complain so much .",
#  'I agree with you on this point .',
#  'She took advantage of my ignorance .',
#  "I couldn 't speak .",
#  'Tom sat down between Mary and her husband .',
#  'This is my pencil .',
#  "I don 't like talking about myself .",
#  'She is about to die .',
#  'I am trying my best .',
#  'Do you want my email address ?',
#  'I see that it is raining .',
#  'Why is my Internet connection so slow ?',
#  'I emailed Tom his homework .',
#  'A poet looks at the world as a man looks at a woman .',
#  "It 's a mistake .",
#  'What do you do ?',
#  'May I eat this bread ?',
#  'A dog is barking .',
#  'My umbrella broke .',
#  'Where are you studying Italian ?',
#  'Have you gone nuts ?',
#  'Watch your mouth !',
#  'She fled her country .',
#  'I found that interesting .',
#  'I like sweets .',
#  'Do you use Facebook ?',
#  "I 'm very busy today .",
#  'He likes to sing in the bathtub .',
#  'I saw that .',
#  'She said that she takes a shower every morning .',
#  'I landed .',
#  'I know Tom and Mary are allergic to peanuts .',
#  "Tom doesn 't have enough friends .",
#  'I teach Spanish .',
#  'Do you have a hernia ?',
#  "But I don 't have money .",
#  'When are you in Munich ?',
#  "Thanks , but I 'll pass .",
#  "You 're all cowards .",
#  'You deserve the prize .',
#  "You 're the one who picked the fight .",
#  'Sami took his shahada .',
#  'English is spoken in many countries .',
#  'Whenever he comes to this place , he orders the same dish .',
#  "You don 't know my brother .",
#  'I wonder who has come .',
#  'My girlfriend is named Laurie .',
#  'I can only go by that which was relayed to me .',
#  '" Whose boots are these ? " " They are Lidya \'s . "',
#  'The thief took flight when the policeman saw him .',
#  'Paraguay has two official languages : Spanish and Guarani .',
#  'The doctor advised me to drink more water to prevent dehydration .',
#  'How is your dad ?',
#  'Try to learn a little English .',
#  'I went to Nagasaki .',
#  'What are you smiling about ?',
#  'Read the label carefully .',
#  'I will tell you the rest tomorrow .',
#  'Agreed , but only on one condition .',
#  'They chose Peter as captain .',
#  'My dad helped me tie my tie .',
#  'You remind me of your brother .',
#  'I have a lot of dreams .',
#  'Please have a seat here .',
#  'I wear jeans almost every day .',
#  'Face facts !',
#  'He brewed beer .',
#  'He is being very kind today .',
#  'A tea with lemon , please .',
#  'The worst riot was in Chicago .',
#  'Tom had an allergic reaction to the medication .',
#  'The files are missing .',
#  'Tom hates Halloween .',
#  'Who did it ?',
#  'There are some differences between British English and American English .',
#  'Did you have a good meal at that restaurant ?',
#  "It 's money down the drain .",
#  "I want to know more about Tom 's biological parents .",
#  'Chemistry is an old science .',
#  'I wonder whether life exists on other planets .',
#  "I haven 't the faintest idea what you mean .",
#  'She finished writing a letter .',
#  'May I speak to the professor ?',
#  'Tom left the country .',
#  'I love Bantu languages .',
#  'He shook his head .',
#  "Tom thinks it 'll be a lot of fun .",
#  'How much are these trousers ?',
#  'Do you speak Nahuatl ?',
#  'Can you write ?',
#  'You look very pale .',
#  'He went up the steps slowly .',
#  'Did you set your phone to airplane mode ?',
#  'Come over to our table .',
#  'How much rent do you pay for the apartment ?',
#  'The boy became happy .',
#  "He won 't take this lightly .",
#  'Murder is against the law .',
#  'The main lobby appears empty .',
#  'Kyoto is famous for its old temples .',
#  "Tom doesn 't like Mary .",
#  "If you want me to help you , you 've got to help me .",
#  'Tom was being disrespectful .',
#  'Tell me something about your country .',
#  'Whose wine is this ?',
#  'Too much money ?',
#  'Neptune is the farthest planet from the Sun .',
#  'Tom is being quiet .',
#  'Just give up .',
#  "The pizza 's ready .",
#  "She 's my rival .",
#  'Do you speak Romanian ?',
#  'Put a sock in it .',
#  "It 's well worth it .",
#  'Talk about huge egos .',
#  'I chose another path .',
#  'Tom turned on the light and walked in .',
#  'Where does Tom live ?',
#  'He fell out of the frying pan into the fire .',
#  'Does the cable fit ?',
#  "Tom didn 't eat anything yesterday .",
#  "I 've been wondering about that .",
#  'We might have frost next week .',
#  'Where did you guys find that ?',
#  'My cousin is the last man but one in the line .',
#  'Creationism is bullshit .',
#  'Do you have friends in Antigua ?',
#  'Tom helped again .',
#  'Do you have any brothers or sisters ?',
#  'I hate waiting .',
#  'Wait a minute .',
#  'Do you want to go ?',
#  "We 're dating .",
#  "It wasn 't just that .",
#  'My girlfriend is Canadian .',
#  'Did you get up at six ?',
#  'Traitors will be deported .',
#  'Ski jumping looks scary .',
#  'Just give him the wallet .',
#  'I did not accept her request .',
#  'How much heroin or methadone do you usually use per day ?',
#  'This road is terrible .',
#  'The dog was dead .',
#  'Quality is more important than quantity .',
#  'It is dangerous to drive so fast .',
#  "I didn 't eat rice .",
#  'I was happy to see people having fun and loving one another .',
#  'He was forbidden to speak .',
#  "You shouldn 't talk back to your parents like that .",
#  "English is difficult , isn 't it ?",
#  'You run .',
#  'Tom cursed .',
#  "I swear I wasn 't there .",
#  'Whose umbrella is this ?',
#  'Sandra takes a slice of bread and a cup of coffee for breakfast .',
#  'I bought a T-shirt .',
#  'Tom intervened .',
#  'She loves him .',
#  'Turn the radio down .',
#  "We don 't know anything about Istanbul .",
#  'We advised them to start early .',
#  'Can you tell us what happened next ?',
#  "Water freezes at zero degrees Celsius , doesn 't it ?",
#  'Give me this hat .',
#  'Belief can move mountains .',
#  'The walls of my room are green .',
#  'Television could be an important source of culture , and its educational broadcasts are valued in many schools .',
#  'No girl in my class is prettier than Linda .',
#  'He comes back from Sydney today .',
#  'We often eat together .',
#  'Water is important .',
#  'What can I do to help you right now ?',
#  'When are you returning to Italy ?',
#  'It was a beautiful sunny day .',
#  'You are here because we need your help .',
#  "I 've already eaten rice .",
#  'Tom preferred games based on new IPs over sequels and remakes .',
#  'I was just joking .',
#  'Man overboard !',
#  'My throat burns .',
#  'Can you recommend me a good camera ?',
#  'First of all , we have to plant all these seeds .',
#  'Bring me the magazines .',
#  'Studying a foreign language is hard .',
#  "You 're right .",
#  'Forget you ever saw me .',
#  'Do it right .',
#  'She worked through the night .',
#  'He made a medal of gold .',
#  'They tried .',
#  'Hello , Lisa !',
#  'Tom laughed at Mary .',
#  'I got your back .',
#  "I don 't want to go bald .",
#  'This house is not for sale .',
#  'Who taught you French ?',
#  'Cyprus is called " Kıbrıs " in Turkish .',
#  'Their only son has been dead for three years .',
#  'I have been to London .',
#  'Most people have very little imagination .',
#  'That was a few years ago .',
#  'I felt happy .',
#  'The child drew a spherical triangle .',
#  'Mary is obsessed about her appearance .',
#  'My package arrived sooner than expected .',
#  'I visit the dentist every two days .',
#  'You told me not to buy that , but I bought it anyway .',
#  "In England the waiter asked us : how much beer would you like ? A half pint , or a pint ? Because we still didn 't know how much that was , we asked him to show us the glasses .",
#  'I love Norwegian !',
#  "We 've got to do something about this problem soon .",
#  'She is wearing a hat .',
#  'Would you like to see a UFO ?',
#  'I must hide .']

# %% [markdown]
# The next code block shows how we loop over the sentences of the article and use the online translation engines. We print out the results per sentence, so we can easily compare the different engines.
#
# Note that the engines are real engines, and that it is possible that they stop offering the service of accepting sentences through an API. As far as I've tested, it seems to work for google and bing, and only sometimes for deepl. These APIs are only intended for research and teaching, so don't overuse them!
#
# The engines apply, by default, automatic source language identification. The target language defaults to English. As we want to translate to Dutch we have to set the target language to `nl`.

# %%
import translators as ts

# %% [markdown]
# We first define a function that takes a sentence, an engine and a target language as input arguments and that strips the translated sentence of potential newline characters at the end of the line. The function also catches the case where the engine does not return anything, so the code will not crash.

# %%
def translate_sentence(sentence, engine, targetlang):
    try:
        out = ts.translate_text(
            sentence,
            translator=engine,
            to_language=targetlang
        )
        return str(out).strip()
    except Exception:
        return "-"

# %% [markdown]
# Then we call the function on the MT engines `bing` and `google`, and keep the results in a python dictionary `results`, which contains one list per engine.
#
# We limit the loop to the translation of the first 30 source lines `[:30]`.

# %%
engines=['bing','google']
targetlang = 'nl'
results = {eng: [] for eng in engines}

for sentence in sourcelines[:30]:
    sentence = sentence.strip()
    if not sentence:
        continue
    print("SRC:",sentence)
    for eng in engines:
      result = translate_sentence(sentence, eng,targetlang)
      print(eng,':',result)
      results[eng].append(result)
    print("\n")
# Out:
# SRC: Nobody reads about my country .
# bing : Niemand leest over mijn land.
# google : Niemand leest over mijn land.
#
#
# SRC: I sleep in my car .
# bing : Ik slaap in mijn auto.
# google : Ik slaap in mijn auto.
#
#
# SRC: There 're clean sheets under the bed .
# bing : Er liggen schone lakens onder het bed.
# google : Er liggen schone lakens onder het bed.
#
#
# SRC: I have a donkey .
# bing : Ik heb een ezel.
# google : Ik heb een ezel.
#
#
# SRC: Betty drives fast .
# bing : Betty rijdt snel.
# google : Betty rijdt snel.
#
#
# SRC: Come to help me .
# bing : Kom me helpen.
# google : Kom mij helpen.
#
#
# SRC: She 's not penniless .
# bing : Ze is niet kansarm.
# google : Ze heeft geen cent .
#
#
# SRC: This mountain is covered in snow all-year-round .
# bing : Deze berg is het hele jaar door met sneeuw bedekt.
# google : Deze berg is het hele jaar door bedekt met sneeuw.
#
#
# SRC: Tom thought Mary was cute .
# bing : Tom vond Mary schattig.
# google : Tom vond Mary schattig.
#
#
# SRC: I don 't suppose it 's possible to read a book by moonlight .
# bing : Ik neem niet aan dat het mogelijk is om bij maanlicht een boek te lezen.
# google : Ik denk niet dat het mogelijk is om een ​​boek bij maanlicht te lezen.
#
#
# SRC: You just have to find her .
# bing : Je hoeft haar alleen maar te vinden.
# google : Je hoeft haar alleen maar te vinden.
#
#
# SRC: It 's very cold today .
# bing : Het is vandaag erg koud.
# google : Het is erg koud vandaag.
#
#
# SRC: Can you ship it to New York City ?
# bing : Kun je het naar New York City verzenden?
# google : Kun je het naar New York City verzenden?
#
#
# SRC: What else does Tom want ?
# bing : Wat wil Tom nog meer?
# google : Wat wil Tom nog meer?
#
#
# SRC: I 'd like to buy a Picasso .
# bing : Ik zou graag een Picasso willen kopen.
# google : Ik wil graag een Picasso kopen.
#
#
# SRC: I don 't mind your groping in the dark for a solution , but I wish you 'd come to a decision .
# bing : Het maakt me niet uit dat je in het donker naar een oplossing tast, maar ik zou willen dat je een beslissing nam.
# google : Ik vind het niet erg dat je in het duister tast naar een oplossing, maar ik zou willen dat je tot een besluit kwam.
#
#
# SRC: Tom has his own business .
# bing : Tom heeft zijn eigen bedrijf.
# google : Tom heeft zijn eigen bedrijf.
#
#
# SRC: Horses run fast .
# bing : Paarden rennen snel.
# google : Paarden rennen snel.
#
#
# SRC: I feel depressed .
# bing : Ik voel me depressief.
# google : Ik voel me depressief.
#
#
# SRC: How did your test go ?
# bing : Hoe is je toets gegaan?
# google : Hoe ging je proef?
#
#
# SRC: What would you do if you were in my place ?
# bing : Wat zou jij doen als je in mijn plaats was?
# google : Wat zou jij doen als je in mijn plaats was?
#
#
# SRC: Take a short cut .
# bing : Neem een kortere weg.
# google : Neem een ​​kortere weg.
#
#
# SRC: What is the name of this river ?
# bing : Wat is de naam van deze rivier?
# google : Wat is de naam van deze rivier?
#
#
# SRC: Lisa speaks not only English but also French .
# bing : Lisa spreekt niet alleen Engels, maar ook Frans.
# google : Lisa spreekt niet alleen Engels maar ook Frans.
#
#
# SRC: Tom said that he needed to go to bed .
# bing : Tom zei dat hij naar bed moest gaan.
# google : Tom zei dat hij naar bed moest.
#
#
# SRC: I don 't drink wine .
# bing : Ik drink geen wijn.
# google : Ik drink geen wijn.
#
#
# SRC: We 're a little busy now .
# bing : We zijn nu een beetje druk.
# google : We hebben het nu een beetje druk.
#
#
# SRC: Tom offended Mary .
# bing : Tom heeft Mary beledigd.
# google : Tom beledigde Maria.
#
#
# SRC: Learn these sentences .
# bing : Leer deze zinnen.
# google : Leer deze zinnen.
#
#
# SRC: It is all delicious !
# bing : Het is allemaal heerlijk!
# google : Het is allemaal heerlijk!

# %% [markdown]
# ##3.4.1.1 DeepL

# %% [markdown]
# In order to automatically translate with DeepL, you first need to create a DeepL account at https://www.deepl.com/en/pro-api, and then go to API keys and limits and click Create key.

# %% [markdown]
# Then we click on the key symbol in the left pane and add a secret key with the name `deepl`. These keys are not visible to people you share the colab session with.
#
# We get the values of these keys using `userdata.get('deepl')` and can use that value to get access to the DeepL web service.

# %%
from google.colab import userdata
auth_key = userdata.get('deepl')

# %% [markdown]
# Then we install the deepl python library

# %%
# !pip install deepl
# Out:
# Requirement already satisfied: deepl in /usr/local/lib/python3.12/dist-packages (1.28.0)
# Requirement already satisfied: requests>=2.32.5 in /usr/local/lib/python3.12/dist-packages (from deepl) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.5->deepl) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.5->deepl) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.5->deepl) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.5->deepl) (2026.1.4)

# %% [markdown]
# Now we translate the first 30 lines and add them to the `results` dictionary and print them to screen.

# %%
import deepl


translator = deepl.Translator(auth_key)

translations = translator.translate_text(sourcelines[:30], target_lang="NL")
results['deepl']=[]

for t in translations:
    print(t.text)
    results['deepl'].append(t.text)
# Out:
# Niemand leest over mijn land.
# Ik slaap in mijn auto.
# Er liggen schone lakens onder het bed.
# Ik heb een ezel.
# Betty rijdt hard.
# Kom me helpen.
# Ze is niet blut.
# Deze berg is het hele jaar door bedekt met sneeuw.
# Tom vond Mary schattig.
# Ik denk niet dat het mogelijk is om bij maanlicht een boek te lezen.
# Je moet haar gewoon vinden.
# Het is vandaag erg koud.
# Kunt u het naar New York City verzenden?
# Wat wil Tom nog meer?
# Ik zou graag een Picasso willen kopen.
# Ik vind het niet erg dat je in het donker naar een oplossing zoekt, maar ik zou willen dat je een beslissing neemt.
# Tom heeft zijn eigen bedrijf.
# Paarden rennen snel.
# Ik voel me depressief.
# Hoe ging je test?
# Wat zou jij doen als je in mijn plaats was?
# Neem een kortere weg.
# Hoe heet deze rivier?
# Lisa spreekt niet alleen Engels, maar ook Frans.
# Tom zei dat hij naar bed moest.
# Ik drink geen wijn.
# We hebben het nu een beetje druk.
# Tom heeft Mary beledigd.
# Leer deze zinnen.
# Het is allemaal heerlijk!

# %% [markdown]
# We can now loop over our dictionary and source sentences again and compare the three engines

# %%
engines=['google','bing','deepl']
for (index,source) in enumerate(sourcelines[:30]):
  print(f'SRC : {source}')
  for engine in engines:
    print(f'{engine} : {results[engine][index]}')
  print("")
# Out:
# SRC : Nobody reads about my country .
# google : Niemand leest over mijn land.
# bing : Niemand leest over mijn land.
# deepl : Niemand leest over mijn land.
#
# SRC : I sleep in my car .
# google : Ik slaap in mijn auto.
# bing : Ik slaap in mijn auto.
# deepl : Ik slaap in mijn auto.
#
# SRC : There 're clean sheets under the bed .
# google : Er liggen schone lakens onder het bed.
# bing : Er liggen schone lakens onder het bed.
# deepl : Er liggen schone lakens onder het bed.
#
# SRC : I have a donkey .
# google : Ik heb een ezel.
# bing : Ik heb een ezel.
# deepl : Ik heb een ezel.
#
# SRC : Betty drives fast .
# google : Betty rijdt snel.
# bing : Betty rijdt snel.
# deepl : Betty rijdt hard.
#
# SRC : Come to help me .
# google : Kom mij helpen.
# bing : Kom me helpen.
# deepl : Kom me helpen.
#
# SRC : She 's not penniless .
# google : Ze heeft geen cent .
# bing : Ze is niet kansarm.
# deepl : Ze is niet blut.
#
# SRC : This mountain is covered in snow all-year-round .
# google : Deze berg is het hele jaar door bedekt met sneeuw.
# bing : Deze berg is het hele jaar door met sneeuw bedekt.
# deepl : Deze berg is het hele jaar door bedekt met sneeuw.
#
# SRC : Tom thought Mary was cute .
# google : Tom vond Mary schattig.
# bing : Tom vond Mary schattig.
# deepl : Tom vond Mary schattig.
#
# SRC : I don 't suppose it 's possible to read a book by moonlight .
# google : Ik denk niet dat het mogelijk is om een ​​boek bij maanlicht te lezen.
# bing : Ik neem niet aan dat het mogelijk is om bij maanlicht een boek te lezen.
# deepl : Ik denk niet dat het mogelijk is om bij maanlicht een boek te lezen.
#
# SRC : You just have to find her .
# google : Je hoeft haar alleen maar te vinden.
# bing : Je hoeft haar alleen maar te vinden.
# deepl : Je moet haar gewoon vinden.
#
# SRC : It 's very cold today .
# google : Het is erg koud vandaag.
# bing : Het is vandaag erg koud.
# deepl : Het is vandaag erg koud.
#
# SRC : Can you ship it to New York City ?
# google : Kun je het naar New York City verzenden?
# bing : Kun je het naar New York City verzenden?
# deepl : Kunt u het naar New York City verzenden?
#
# SRC : What else does Tom want ?
# google : Wat wil Tom nog meer?
# bing : Wat wil Tom nog meer?
# deepl : Wat wil Tom nog meer?
#
# SRC : I 'd like to buy a Picasso .
# google : Ik wil graag een Picasso kopen.
# bing : Ik zou graag een Picasso willen kopen.
# deepl : Ik zou graag een Picasso willen kopen.
#
# SRC : I don 't mind your groping in the dark for a solution , but I wish you 'd come to a decision .
# google : Ik vind het niet erg dat je in het duister tast naar een oplossing, maar ik zou willen dat je tot een besluit kwam.
# bing : Het maakt me niet uit dat je in het donker naar een oplossing tast, maar ik zou willen dat je een beslissing nam.
# deepl : Ik vind het niet erg dat je in het donker naar een oplossing zoekt, maar ik zou willen dat je een beslissing neemt.
#
# SRC : Tom has his own business .
# google : Tom heeft zijn eigen bedrijf.
# bing : Tom heeft zijn eigen bedrijf.
# deepl : Tom heeft zijn eigen bedrijf.
#
# SRC : Horses run fast .
# google : Paarden rennen snel.
# bing : Paarden rennen snel.
# deepl : Paarden rennen snel.
#
# SRC : I feel depressed .
# google : Ik voel me depressief.
# bing : Ik voel me depressief.
# deepl : Ik voel me depressief.
#
# SRC : How did your test go ?
# google : Hoe ging je proef?
# bing : Hoe is je toets gegaan?
# deepl : Hoe ging je test?
#
# SRC : What would you do if you were in my place ?
# google : Wat zou jij doen als je in mijn plaats was?
# bing : Wat zou jij doen als je in mijn plaats was?
# deepl : Wat zou jij doen als je in mijn plaats was?
#
# SRC : Take a short cut .
# google : Neem een ​​kortere weg.
# bing : Neem een kortere weg.
# deepl : Neem een kortere weg.
#
# SRC : What is the name of this river ?
# google : Wat is de naam van deze rivier?
# bing : Wat is de naam van deze rivier?
# deepl : Hoe heet deze rivier?
#
# SRC : Lisa speaks not only English but also French .
# google : Lisa spreekt niet alleen Engels maar ook Frans.
# bing : Lisa spreekt niet alleen Engels, maar ook Frans.
# deepl : Lisa spreekt niet alleen Engels, maar ook Frans.
#
# SRC : Tom said that he needed to go to bed .
# google : Tom zei dat hij naar bed moest.
# bing : Tom zei dat hij naar bed moest gaan.
# deepl : Tom zei dat hij naar bed moest.
#
# SRC : I don 't drink wine .
# google : Ik drink geen wijn.
# bing : Ik drink geen wijn.
# deepl : Ik drink geen wijn.
#
# SRC : We 're a little busy now .
# google : We hebben het nu een beetje druk.
# bing : We zijn nu een beetje druk.
# deepl : We hebben het nu een beetje druk.
#
# SRC : Tom offended Mary .
# google : Tom beledigde Maria.
# bing : Tom heeft Mary beledigd.
# deepl : Tom heeft Mary beledigd.
#
# SRC : Learn these sentences .
# google : Leer deze zinnen.
# bing : Leer deze zinnen.
# deepl : Leer deze zinnen.
#
# SRC : It is all delicious !
# google : Het is allemaal heerlijk!
# bing : Het is allemaal heerlijk!
# deepl : Het is allemaal heerlijk!

# %%
results['deepl']
# Out:
# ['Niemand leest over mijn land.',
#  'Ik slaap in mijn auto.',
#  'Er liggen schone lakens onder het bed.',
#  'Ik heb een ezel.',
#  'Betty rijdt hard.',
#  'Kom me helpen.',
#  'Ze is niet blut.',
#  'Deze berg is het hele jaar door bedekt met sneeuw.',
#  'Tom vond Mary schattig.',
#  'Ik denk niet dat het mogelijk is om bij maanlicht een boek te lezen.',
#  'Je moet haar gewoon vinden.',
#  'Het is vandaag erg koud.',
#  'Kunt u het naar New York City verzenden?',
#  'Wat wil Tom nog meer?',
#  'Ik zou graag een Picasso willen kopen.',
#  'Ik vind het niet erg dat je in het donker naar een oplossing zoekt, maar ik zou willen dat je een beslissing neemt.',
#  'Tom heeft zijn eigen bedrijf.',
#  'Paarden rennen snel.',
#  'Ik voel me depressief.',
#  'Hoe ging je test?',
#  'Wat zou jij doen als je in mijn plaats was?',
#  'Neem een kortere weg.',
#  'Hoe heet deze rivier?',
#  'Lisa spreekt niet alleen Engels, maar ook Frans.',
#  'Tom zei dat hij naar bed moest.',
#  'Ik drink geen wijn.',
#  'We hebben het nu een beetje druk.',
#  'Tom heeft Mary beledigd.',
#  'Leer deze zinnen.',
#  'Het is allemaal heerlijk!']

# %% [markdown]
# ##3.4.1.2 Save the outputs to files

# %% [markdown]
# Now that we've translated 30 sentences with 3 different MT engines, we store the results, so we can reuse and evaluate them later.

# %%
for engine, outputs in results.items():
    with open(f"tatoeba-{engine}.txt", "w") as f:
        for sent in outputs:
            f.write(sent + "\n")

# %% [markdown]
# The above made local copies. We need to copy them to a path in our Google Drive, using `!cp`.

# %%
# !cp tatoeba-*.txt drive/MyDrive/MTAT/.../tatoeba/

# %% [markdown]
# # 3.4.2 Automatic metrics

# %% [markdown]
# In this section we’ll demonstrate how to calculate several evaluation metrics.

# %% [markdown]
# ##3.4.2.1 MaTEO: Machine Translation Evaluation Online
#
# In this hands-on section, we focus on automatic evaluation: computing quantitative scores that summarise how close a system output is to one or more reference translations.
#
# A practical way to do this is MATEO (MAchine Translation Evaluation Online) available at https://mateo.ivdnt.org/, a web-based interface that lets you upload MT outputs and obtain scores from a battery of established metrics in a single, consistent evaluation pipeline. Tools like MATEO make it easier to compare systems, settings, or datasets without re-implementing evaluation code each time—while also reminding us that metric scores are proxies that must be
# interpreted with care.
#
# The online version will only work for relatively small files, not for test files with thousands of sentences.
#
# ### Exercise: Evaluate the three engines with MATEO
# Use the tatoeba-engine.txt files that you just created to evaluate the engines with MATEO. Remember that you need to create a version of only 30 sentences for the source and the reference files. (You can use the `!head` command for that).

# %% [markdown]
# The reference file is found here: https://raw.githubusercontent.com/VincentCCL/MTAT/refs/heads/main/data/tatoeba-en-nl/dev.nl
#
# Interpret the results.

# %% [markdown]
# ##3.4.2.2 SacreBLEU: BLEU scores / chrF / TER

# %% [markdown]
# There is a python library that allows us to calculate BLEU scores easily. We first need to install it.

# %%
# !pip -q install -U sacrebleu
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 3.3 MB/s eta 0:00:00

# %% [markdown]
#  Now we can use SacreBleu from within python, but we can also use it as a command on the commandline.

# %% [markdown]
# ### In python

# %% [markdown]
# First we need to import the metrics

# %%
from sacrebleu.metrics import BLEU, CHRF, TER

# %% [markdown]
# Then we need a list of references. Be aware that this should be a list of lists, as we can have multiple references per source sentence.
#
# And of course we also need system output.

# %%
refs = [ # First set of references
           ['The dog bit the man.', 'It was not unexpected.', 'The man bit him first.'],
         # Second set of references
           ['The dog had bit the man.', 'No one was surprised.', 'The man had bitten the dog.'],
       ]
sys = ['The dog bit the man.', "It wasn't surprising.", 'The man had just bitten him.']

# %% [markdown]
# Then we can calculate the scores like this:

# %%
bleu = BLEU()
bleu.corpus_score(sys, refs)
# Out:
# BLEU = 48.53 82.4/50.0/45.5/37.5 (BP = 0.943 ratio = 0.944 hyp_len = 17 ref_len = 18)

# %%
chrf = CHRF()
chrf.corpus_score(sys, refs)
# Out:
# chrF2 = 59.73

# %%
ter = TER()
ter.corpus_score(sys,refs)
# Out:
# TER = 40.00

# %% [markdown]
# ### Command line

# %% [markdown]
# To test this, we can download some automatically translated sentences from Romanian into Portuguese, automatically transcribed from a speech file. These sentences come from an experiment at the European Parliament where three anonymous commercial companies performed speech translation on a speech from Romanian to Portuguese. It is only a very short fragment.

# %%
# !wget https://github.com/VincentCCL/MTAT/raw/refs/heads/main/data/ep/RO_PT_AV.zip
# !unzip RO_PT_AV.zip
# Out:
# --2026-02-18 15:30:11--  https://github.com/VincentCCL/MTAT/raw/refs/heads/main/data/ep/RO_PT_AV.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/VincentCCL/MTAT/refs/heads/main/data/ep/RO_PT_AV.zip [following]
# --2026-02-18 15:30:11--  https://raw.githubusercontent.com/VincentCCL/MTAT/refs/heads/main/data/ep/RO_PT_AV.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2704 (2.6K) [application/zip]
# Saving to: ‘RO_PT_AV.zip’
#
# RO_PT_AV.zip        100%[===================>]   2.64K  --.-KB/s    in 0s
#
# 2026-02-18 15:30:11 (45.0 MB/s) - ‘RO_PT_AV.zip’ saved [2704/2704]
#
# Archive:  RO_PT_AV.zip
#   inflating: RO_PT_AdinaValean_A.txt.mt.tok.align
#   inflating: RO_PT_AdinaValean_B.txt.mt.tok.align
#   inflating: RO_PT_AdinaValean_C.txt.mt.tok.align
#   inflating: RO_PT_AdinaValean_REF.txt.sent

# %% [markdown]
# This gives us the results of the automatic translation by three MT engines of the same snippet of speech in the European Parliament. It also includes a reference translation.

# %%
# !sacrebleu RO_PT_AdinaValean_REF.txt.sent -i RO_PT_AdinaValean_A.txt.mt.tok.align -m bleu ter chrf
# Out:
# [
# {
#  "name": "BLEU",
#  "score": 23.5,
#  "signature": "nrefs:1|case:mixed|eff:no|tok:13a|smooth:exp|version:2.6.0",
#  "verbose_score": "49.4/26.4/18.2/12.8 (BP = 1.000 ratio = 1.108 hyp_len = 164 ref_len = 148)",
#  "nrefs": "1",
#  "case": "mixed",
#  "eff": "no",
#  "tok": "13a",
#  "smooth": "exp",
#  "version": "2.6.0"
# },
# {
#  "name": "chrF2",
#  "score": 50.6,
#  "signature": "nrefs:1|case:mixed|eff:yes|nc:6|nw:0|space:no|version:2.6.0",
#  "nrefs": "1",
#  "case": "mixed",
#  "eff": "yes",
#  "nc": "6",
#  "nw": "0",
#  "space": "no",
#  "version": "2.6.0"
# },
# {
#  "name": "TER",
#  "score": 71.6,
#  "signature": "nrefs:1|case:lc|tok:tercom|norm:no|punct:yes|asian:no|version:2.6.0",
#  "nrefs": "1",
#  "case": "lc",
#  "tok": "tercom",
#  "norm": "no",
#  "punct": "yes",
#  "asian": "no",
#  "version": "2.6.0"
# }
# ]

# %% [markdown]
# ### Exercise
# Take the bing, google and deepl translations we made for the first 30 tatoeba sentences and calculate their BLEU, TER and chrF scores, using the command line or python approaches.

# %%
# Put your code here

# %% [markdown]
# ##3.4.2.3 Significance levels for BLEU / chrF / TER
# Sacrebleu also allows you to calculate whether the difference in scores is significant. In order to calculate this we need to give sacrebleu the output of (at least) two MT systems, and add the `--paired-bs` option.

# %%
# !sacrebleu reference_file -i mt-output-file_baseline mt-output-file_system2 mt-output-file_systenm3 ... -m metrics --paired-bs
# Out:
# usage: sacrebleu [-h] [--citation] [--list] [--test-set TEST_SET]
#                  [--language-pair LANGPAIR] [--origlang ORIGLANG]
#                  [--subset SUBSET] [--download DOWNLOAD]
#                  [--echo ECHO [ECHO ...]] [--input [INPUT ...]]
#                  [--num-refs NUM_REFS] [--encoding ENCODING]
#                  [--metrics {bleu,chrf,ter} [{bleu,chrf,ter} ...]]
#                  [--sentence-level] [--smooth-method {none,floor,add-k,exp}]
#                  [--smooth-value BLEU_SMOOTH_VALUE]
#                  [--tokenize {none,zh,13a,intl,char,ja-mecab,ko-mecab,spm,flores101,flores200,spBLEU-1K}]
#                  [--lowercase] [--force] [--chrf-char-order CHRF_CHAR_ORDER]
#                  [--chrf-word-order CHRF_WORD_ORDER] [--chrf-beta CHRF_BETA]
#                  [--chrf-whitespace] [--chrf-lowercase] [--chrf-eps-smoothing]
#                  [--ter-case-sensitive] [--ter-asian-support] [--ter-no-punct]
#                  [--ter-normalized] [--confidence]
#                  [--confidence-n CONFIDENCE_N] [--paired-ar | --paired-bs]
#                  [--paired-ar-n PAIRED_AR_N] [--paired-bs-n PAIRED_BS_N]
#                  [--paired-jobs PAIRED_JOBS] [--quiet] [--short]
#                  [--score-only] [--width WIDTH] [--detail] [--no-color]
#                  [--format {json,text,latex}] [--version]
#                  [refs ...]
# sacrebleu: error: argument --metrics/-m: invalid choice: 'metrics' (choose from bleu, chrf, ter)

# %%
# !sacrebleu RO_PT_AdinaValean_REF.txt.sent -i RO_PT_AdinaValean_A.txt.mt.tok.align RO_PT_AdinaValean_B.txt.mt.tok.align RO_PT_AdinaValean_C.txt.mt.tok.align -m bleu ter chrf --paired-bs --format text
# Out:
# sacreBLEU: Found 3 systems.
# sacreBLEU: Pre-computing BLEU statistics for 'Baseline: RO_PT_AdinaValean_A.txt.mt.tok.align'
# sacreBLEU: Pre-computing TER statistics for 'Baseline: RO_PT_AdinaValean_A.txt.mt.tok.align'
# sacreBLEU: Pre-computing CHRF statistics for 'Baseline: RO_PT_AdinaValean_A.txt.mt.tok.align'
# sacreBLEU: Computing BLEU for 'RO_PT_AdinaValean_B.txt.mt.tok.align' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing TER for 'RO_PT_AdinaValean_B.txt.mt.tok.align' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing chrF2 for 'RO_PT_AdinaValean_B.txt.mt.tok.align' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing BLEU for 'RO_PT_AdinaValean_C.txt.mt.tok.align' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing TER for 'RO_PT_AdinaValean_C.txt.mt.tok.align' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing chrF2 for 'RO_PT_AdinaValean_C.txt.mt.tok.align' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# ╒════════════════════════════════════════════════╤═════════════════════╤════════════════════╤══════════════════════╕
# │                                         System │  BLEU (μ ± 95% CI)  │  TER (μ ± 95% CI)  │  chrF2 (μ ± 95% CI)  │
# ╞════════════════════════════════════════════════╪═════════════════════╪════════════════════╪══════════════════════╡
# │ Baseline: RO_PT_AdinaValean_A.txt.mt.tok.align │  23.5 (22.9 ± 9.9)  │ 71.6 (72.1 ± 13.2) │  50.6 (50.5 ± 5.5)   │
# ├────────────────────────────────────────────────┼─────────────────────┼────────────────────┼──────────────────────┤
# │           RO_PT_AdinaValean_B.txt.mt.tok.align │ 24.0 (22.8 ± 12.1)  │ 64.2 (64.5 ± 8.2)  │  52.7 (52.6 ± 5.5)   │
# │                                                │    (p = 0.3017)     │   (p = 0.0010)*    │     (p = 0.1019)     │
# ├────────────────────────────────────────────────┼─────────────────────┼────────────────────┼──────────────────────┤
# │           RO_PT_AdinaValean_C.txt.mt.tok.align │  24.0 (22.6 ± 7.7)  │ 72.3 (71.9 ± 8.2)  │  47.3 (47.3 ± 4.6)   │
# │                                                │    (p = 0.3926)     │    (p = 0.4815)    │    (p = 0.0110)*     │
# ╘════════════════════════════════════════════════╧═════════════════════╧════════════════════╧══════════════════════╛
#
# ------------------------------------------------------------
# Paired bootstrap resampling test with 1000 resampling trials
# ------------------------------------------------------------
#  - Each system is pairwise compared to Baseline: RO_PT_AdinaValean_A.txt.mt.tok.align.
#    Actual system score / bootstrap estimated true mean / 95% CI are provided for each metric.
#
#  - Null hypothesis: the system and the baseline translations are essentially
#    generated by the same underlying process. For a given system and the baseline,
#    the p-value is roughly the probability of the absolute score difference (delta)
#    or higher occurring due to chance, under the assumption that the null hypothesis is correct.
#
#  - Assuming a significance threshold of 0.05, the null hypothesis can be rejected
#    for p-values < 0.05 (marked with "*"). This means that the delta is unlikely to be attributed
#    to chance, hence the system is significantly "different" than the baseline.
#    Otherwise, the p-values are highlighted in red.
#
#  - NOTE: Significance does not tell whether a system is "better" than the baseline but rather
#    emphasizes the "difference" of the systems in terms of the replicability of the delta.
#
# -----------------
# Metric signatures
# -----------------
#  - BLEU       nrefs:1|bs:1000|seed:12345|case:mixed|eff:no|tok:13a|smooth:exp|version:2.6.0
#  - TER        nrefs:1|bs:1000|seed:12345|case:lc|tok:tercom|norm:no|punct:yes|asian:no|version:2.6.0
#  - chrF2      nrefs:1|bs:1000|seed:12345|case:mixed|eff:yes|nc:6|nw:0|space:no|version:2.6.0

# %% [markdown]
# #3.4.3 BERTScore

# %% [markdown]
# ##3.4.3.1 Hugging Face access token (BERTScore)
#
# BERTScore relies on pretrained Transformer models that are downloaded from
# the **Hugging Face Hub**. To access these models, you need a **Hugging Face
# account** and a **read-only access token**.
#
# If you do not yet have a Hugging Face account:
#
# 1. Go to https://huggingface.co
# 2. Create a free account (or log in if you already have one).
# 3. Navigate to **Access Tokens**.
# 4. Create a new token with role **Read** and copy the token (it starts with
#    `hf_...`).
#
# In Google Colab, this token must be stored as a **secret**:
#
# 1. Click the 🔑 **Secrets** icon in the left sidebar.
# 2. Add a new secret with:
#    - **Name:** `HF_TOKEN`
#    - **Value:** your Hugging Face access token
# 3. Save the secret.
#
# Once the token is stored as a secret, it is automatically made available to
# Python libraries in the notebook. No additional authentication code is
# required when running BERTScore from Python.
#
# If the token is missing or invalid, the model download will fail. After the
# model has been downloaded once, it is cached and reused for the remainder
# of the Colab session.

# %% [markdown]
# To make the token available for command-line commands, execute this code:

# %%
from google.colab import userdata
from huggingface_hub import login

hf_token = userdata.get("HF_TOKEN")
login(hf_token)

# %% [markdown]
# ## 3.4.3.2 Running BERTScore
#
# We first need to instal the appropriate module.

# %%
# !pip -q install bert-score

# %% [markdown]
# And we have a bit of data in this format:

# %%
refs_bertscore = [
    'The dog bit the man. ||| The dog had bit the man.',
    'It was not unexpected. ||| No one was surprised.',
    'The man bit him first. ||| The man had bitten the dog.',
]

sys = ['The dog bit the man.', "It wasn't surprising.", 'The man had just bitten him.']

# %% [markdown]
# Then we can calculate BERTScore Precision, Recall and F-score with the following command. Note that you need to set the target language explicitly.

# %%
from bert_score import score
(P, R, F), hashname = score(sys, refs_bertscore, lang="en", return_hash=True)
print(
    f"{hashname}: P={P.mean().item():.6f} R={R.mean().item():.6f} F={F.mean().item():.6f}"
)
# Out:
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.weight            | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# roberta-large_L17_no-idf_version=0.3.12(hug_trans=5.0.0): P=0.957206 R=0.915080 F=0.935619

# %% [markdown]
# With the command-line on the previously downloaded files from the European Parliament

# %%
# !bert-score \
  -r RO_PT_AdinaValean_REF.txt.sent \
  -c RO_PT_AdinaValean_A.txt.mt.tok.align \
  --lang pt \
  --m xlm-roberta-large
# Out:
# Loading weights: 100% 391/391 [00:00<00:00, 916.56it/s, Materializing param=pooler.dense.weight]
# XLMRobertaModel LOAD REPORT from: xlm-roberta-large
# Key                       | Status     |  |
# --------------------------+------------+--+-
# lm_head.layer_norm.bias   | UNEXPECTED |  |
# lm_head.dense.weight      | UNEXPECTED |  |
# lm_head.dense.bias        | UNEXPECTED |  |
# lm_head.bias              | UNEXPECTED |  |
# lm_head.layer_norm.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# xlm-roberta-large_L17_no-idf_version=0.3.12(hug_trans=5.0.0)_fast-tokenizer P: 0.928678 R: 0.927544 F1: 0.928097

# %% [markdown]
# ### Exercise
# * Calculate BERT-score on the 30 sentences from the corpus we've translated for bing, google and deepl.

# %% [markdown]
# #3.4.4 BLEURT

# %% [markdown]
# First, we install:

# %%
# !pip install -q git+https://github.com/google-research/bleurt.git
# !pip install -q huggingface_hub
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for BLEURT (setup.py) ... done

# %% [markdown]
# Then, we download a TF BLEURT-20 checkpoint mirror from Hugging Face.

# %%
from huggingface_hub import snapshot_download

ckpt_dir = snapshot_download(
    repo_id="BramVanroy/BLEURT-20",
    local_dir="bleurt-20",
    local_dir_use_symlinks=False
)
print("Checkpoint in:", ckpt_dir)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:202: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `snapshot_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Checkpoint in: /content/bleurt-20

# %% [markdown]
# And this is how we run Bleurt.

# %%
# 3) Score
from bleurt import score
references = ["This is a test."]
candidates = ["This is the test."]

scorer = score.BleurtScorer("bleurt-20")
scores = scorer.score(references=references, candidates=candidates)
print("BLEURT mean:", sum(scores)/len(scores))
# Out:
# BLEURT mean: 0.7928391098976135

# %% [markdown]
# #3.4.5 COMET

# %% [markdown]
# To get COMET to work requires us to start a new colab session, as it is not compatible with the things we've previously installed. You can find it [HERE](https://colab.research.google.com/drive/1m65-TU26XJYaXBNRkjlxDd1_oYtAhgLI?usp=sharing)
