# %% [markdown]
# <a href="https://colab.research.google.com/github/VincentCCL/MTAT/blob/main/notebooks/MTAT26_RNN_Encoder_Decoder_Scaled_up.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Scaling up

# %%
# !pip install sacrebleu

# %%
# !wget https://www.ccl.kuleuven.be/~vincent/MTAT/rnn_seq2seq.py
# Out:
# --2026-01-09 11:17:23--  https://www.ccl.kuleuven.be/~vincent/MTAT/rnn_seq2seq.py
# Resolving www.ccl.kuleuven.be (www.ccl.kuleuven.be)... 134.58.16.193
# Connecting to www.ccl.kuleuven.be (www.ccl.kuleuven.be)|134.58.16.193|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 62329 (61K) [text/plain]
# Saving to: ‘rnn_seq2seq.py.1’
#
# rnn_seq2seq.py.1    100%[===================>]  60.87K   127KB/s    in 0.5s
#
# 2026-01-09 11:17:25 (127 KB/s) - ‘rnn_seq2seq.py.1’ saved [62329/62329]

# %%
# !cp "/content/drive/MyDrive/Vakken/MTAT/2026/tatoeba/train.en" .
# !cp "/content/drive/MyDrive/Vakken/MTAT/2026/tatoeba/train.nl" .
# !cp "/content/drive/MyDrive/Vakken/MTAT/2026/tatoeba/dev.en" .
# !cp "/content/drive/MyDrive/Vakken/MTAT/2026/tatoeba/dev.nl" .
# !cp "/content/drive/MyDrive/Vakken/MTAT/2026/tatoeba/test.en" .
# !cp "/content/drive/MyDrive/Vakken/MTAT/2026/tatoeba/test.nl" .

# %% [markdown]
# ```
# Seq 2 Seq default values:
# --epochs 30
# --batch-size 32
# --emb-size 64
# --hidden-dize 128
# --max-len 20
# --lr 1e-3  (learning rate)
# --teacher-forcing  (default 0.7)
# --enc-layers 1
# --dec-layers 1
# --rnn-type rnn (gru / lstm)
# ```

# %% [markdown]
# ## RNN as in 2014

# %% [markdown]
# ### train

# %%
# !python rnn_seq2seq.py --src-file train.en --tgt-file train.nl \
--src-val dev.en --tgt-val dev.nl \
--rnn-type rnn \
--enc-layers 1 --dec-layers 1 \
--emb-size 256 --hidden-size 512 \
--epochs 3 \
--save /content/drive/MyDrive/Vakken/MTAT/2026/rnns/rnn_baseline.pt \
--show-val-examples 10 \
--eval-metrics \
--lower \
--history-json /content/drive/MyDrive/Vakken/MTAT/2026/rnns/rnn.hist
# Out:
# usage: rnn_seq2seq.py [-h] [--src-file SRC_FILE] [--tgt-file TGT_FILE]
#                       [--src-val SRC_VAL] [--tgt-val TGT_VAL]
#                       [--mode {train,translate}] [--epochs EPOCHS]
#                       [--batch-size BATCH_SIZE] [--emb-size EMB_SIZE]
#                       [--hidden-size HIDDEN_SIZE] [--max-len MAX_LEN]
#                       [--lr LR] [--teacher-forcing TEACHER_FORCING]
#                       [--enc-layers ENC_LAYERS] [--dec-layers DEC_LAYERS]
#                       [--rnn-type {rnn,gru,lstm}] [--attention {none,luong}]
#                       [--bidirectional] [--limit LIMIT]
#                       [--max-src-vocab MAX_SRC_VOCAB]
#                       [--max-tgt-vocab MAX_TGT_VOCAB] [--lower]
#                       [--subword-type {none,bpe,unigram}]
#                       [--src-sp-model SRC_SP_MODEL]
#                       [--tgt-sp-model TGT_SP_MODEL] [--save SAVE]
#                       [--save-best SAVE_BEST] [--load LOAD]
# ...

# %% [markdown]
# ### Plotting the learning curve
#
# Here's a program that allows plotting the curves

# %% [markdown]
# First we need to download the program.

# %%
# !wget https://www.ccl.kuleuven.be/~vincent/MTAT/plot_history.py
# Out:
# --2026-01-09 12:58:03--  https://www.ccl.kuleuven.be/~vincent/MTAT/plot_history.py
# Resolving www.ccl.kuleuven.be (www.ccl.kuleuven.be)... 134.58.16.193
# Connecting to www.ccl.kuleuven.be (www.ccl.kuleuven.be)|134.58.16.193|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1672 (1.6K)
# Saving to: ‘plot_history.py’
#
# plot_history.py     100%[===================>]   1.63K  --.-KB/s    in 0s
#
# 2026-01-09 12:58:03 (407 MB/s) - ‘plot_history.py’ saved [1672/1672]

# %% [markdown]
# Then we can run it.

# %%
# !python plot_history.py /content/drive/MyDrive/Vakken/MTAT/2026/rnns/rnn.hist --save /content/drive/MyDrive/Vakken/MTAT/2026/rnns/rnn_nll.png
# Out:
# Traceback (most recent call last):
#   File "/content/plot_history.py", line 61, in <module>
#     main()
#   File "/content/plot_history.py", line 52, in main
#     plot_histories(
#   File "/content/plot_history.py", line 16, in plot_histories
#     history = load_history(path)
#               ^^^^^^^^^^^^^^^^^^
#   File "/content/plot_history.py", line 8, in load_history
#     with open(path, "r", encoding="utf-8") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Vakken/MTAT/2026/rnns/rnn.hist'

# %%
from IPython.display import Image, display
display(Image(filename="/content/drive/MyDrive/Vakken/MTAT/2026/rnns/rnn_nll.png"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-305780431.py in <cell line: 0>()
#       1 from IPython.display import Image, display
# ----> 2 display(Image(filename="/content/drive/MyDrive/Vakken/MTAT/2026/rnns/rnn_nll.png"))
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# ...

# %%
# !python plot_history.py /content/drive/MyDrive/Vakken/MTAT/2026/rnns/rnn.hist \
 --metric bleu \
  --save /content/drive/MyDrive/Vakken/MTAT/2026/rnns/rnn_bleu.png

# %%
from IPython.display import Image, display
display(Image(filename="/content/drive/MyDrive/Vakken/MTAT/2026/rnns/rnn_bleu.png"))

# %% [markdown]
# ## Replacing RNN with GRU

# %%
# !python rnn_seq2seq.py --src-file train.en --tgt-file train.nl \
--src-val dev.en --tgt-val dev.nl \
--rnn-type gru \
--enc-layers 1 --dec-layers 1 \
--emb-size 256 --hidden-size 512 \
--epochs 10 \
--save /content/drive/MyDrive/Vakken/MTAT/2026/rnns/gru.pt \
--show-val-examples 3 \
--eval-metrics \
--lower \
--history-json /content/drive/MyDrive/Vakken/MTAT/2026/rnns/gru.hist

# %% [markdown]
# ## Replacing with LSTM

# %%
# !python rnn_seq2seq.py --src-file train.en --tgt-file train.nl \
--src-val dev.en --tgt-val dev.nl \
--rnn-type lstm \
--enc-layers 1 --dec-layers 1 \
--emb-size 256 --hidden-size 512 \
--epochs 10 \
--save /content/drive/MyDrive/Vakken/MTAT/2026/rnns/lstm.pt \
--show-val-examples 3 \
--eval-metrics \
--lower \
--history-json /content/drive/MyDrive/Vakken/MTAT/2026/rnns/lstm.hist

# %% [markdown]
# ## Plot multiple histories
