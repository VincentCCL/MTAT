# %%
# !pip install -q --no-cache-dir "transformers==4.50.0" sentencepiece accelerate evaluate sacrebleu
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 128.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 285.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 276.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 385.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 333.1 MB/s eta 0:00:00

# %%
import importlib
import sys

# Remove already loaded transformers modules
for m in list(sys.modules):
    if m.startswith("transformers"):
        del sys.modules[m]

import transformers
importlib.reload(transformers)

print("Transformers version:", transformers.__version__)
# Out:
# Transformers version: 4.50.0

# %%
assert transformers.__version__.startswith("4.50"), "Wrong transformers version"

# %%
# !wget https://raw.githubusercontent.com/VincentCCL/MTAT/refs/heads/main/code/madlad_translate.py
# Out:
# --2026-03-20 09:24:51--  https://raw.githubusercontent.com/VincentCCL/MTAT/refs/heads/main/code/madlad_translate.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4334 (4.2K) [text/plain]
# Saving to: ‘madlad_translate.py’
#
# madlad_translate.py 100%[===================>]   4.23K  --.-KB/s    in 0s
#
# 2026-03-20 09:24:51 (51.1 MB/s) - ‘madlad_translate.py’ saved [4334/4334]

# %%
# %run madlad_translate.py \
  --model-dir google/madlad400-3b-mt \
  --src-lang en \
  --tgt-lang nl \
  --src-file /kaggle/input/datasets/vincentvandeghinste/tatoeba-en-nl/dev.en \
  --out-file dev.madlad.nl \
  --ref-file /kaggle/input/datasets/vincentvandeghinste/tatoeba-en-nl/dev.nl \
  --metrics bleu,chrf \
  --batch-size 4 \
  --max-src-len 128 \
  --max-gen-len 64 \
  --num-beams 4
# Out:
# 2026-03-20 09:25:02.844619: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773998703.060761      25 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773998703.125078      25 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773998703.660139      25 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
